# %% [markdown]
# # ETTh1 Forecast Runner
#
# 실행 로직은 `ett_forecasting_pytorch.py`에 있습니다. 앞으로 모델이나 학습 코드를 바꿀 때는 `.py` 파일만 수정하고, 이 노트북은 다시 열 필요 없이 아래 셀을 재실행하면 됩니다.

# %%
import importlib
import sys
from pathlib import Path

PROJECT_DIR = Path("/content/drive/MyDrive/2026_DeepSyS")

try:
    from google.colab import drive
    if not PROJECT_DIR.exists():
        drive.mount("/content/drive")
except ModuleNotFoundError:
    pass

if str(PROJECT_DIR) not in sys.path:
    sys.path.insert(0, str(PROJECT_DIR))

import ett_forecasting_pytorch as ett

importlib.reload(ett)
result = ett.run(plot=True)

# %%
result["baseline"], result["metric"], result["submit"].head()
